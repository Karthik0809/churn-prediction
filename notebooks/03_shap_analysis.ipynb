# %% [markdown]
# # 03 — SHAP Explainability
#
# Generate global feature importance using SHAP for the trained XGBoost model.
#
# Outputs:
# - `assets/shap_summary.png`
# - `assets/top5_shap_drivers.txt`

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %%
# Ensure model exists
from src.data_processing import main as build_db
from src.model import train_xgb

build_db()
train_xgb()

# %%
# Run SHAP generation using the project script
from src.shap_analysis import run_shap

run_shap()
